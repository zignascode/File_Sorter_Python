# %% [markdown]
# # FileSorter is an script to sort and classify files

# %%
#Library imports
import pandas as pd #For data manipulation and analysis
import os #For operating system related functions
import hashlib as hl #For hashing files to check for duplicates

# %%
#Getting the list of files in the current directory
ls_files = [] #List with only files, no directories

for file in os.listdir():
    #If the item is a file, add it to the ls_fix list
    if os.path.isfile(file): ls_files.append(file)

#ls_files

# %%
#Testing the hashing of a file

for i in range(0,len(ls_files)):
    with open(ls_files[i], "rb") as door_file: #Needs to process with "with" to close automaticaly
        content = door_file.read() #Variable with the binary content of the file
        #End of the idented block

    hf = hl.sha1(content).hexdigest() #No needs update() because there are simple files
    print(hf)
# Out:
# b9fbebeaa265ec0ff8bfabb313c0e89fcc28b44c
# dd6a6dbd2d02294c2e6d8f51bcbcdf0b8cf75e73
# dcb8898dbccc95e51c0839e5659281a13eb9ace6
# 382a59790a615d5dde0ed9039993e0dfa18f6211
# 127d8e83f371526750eb63a526988c2413938654
# 2c48a6ff731793638571dd900ea7848a8d15e6c4
# 405d52b80008a6828f3a2e2f35465f7d6019dbfa
